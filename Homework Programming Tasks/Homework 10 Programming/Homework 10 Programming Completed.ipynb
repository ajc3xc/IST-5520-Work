# %% [markdown]
# # Homework 10 Programming

# %% [markdown]
# ## Task A: Data Manipulation

# %% [markdown]
# #### Import data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DC_Bike_Rentals.csv')

df.head()
# Out:
#    hour  season  holiday  workingday  weather  temp   atemp  humidity  \
# 0     0       1        0           0        1  9.84  14.395        81
# 1     1       1        0           0        1  9.02  13.635        80
# 2     2       1        0           0        1  9.02  13.635        80
# 3     3       1        0           0        1  9.84  14.395        75
# 4     4       1        0           0        1  9.84  14.395        75
#
#    windspeed  count
# 0        0.0     16
# 1        0.0     40
# 2        0.0     32
# 3        0.0     13
# 4        0.0      1

# %% [markdown]
# #### Show data types

# %%
df.dtypes
# Out:
# hour            int64
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# count           int64
# dtype: object

# %% [markdown]
# #### Seperate into predictors and target

# %%
y, X = df['count'], df.loc[:, df.columns != 'count']

# %% [markdown]
# #### Split into test and training datasets

# %%
#import module
from sklearn.model_selection import train_test_split

#split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42)

# %%
#show results
X_train.shape
# Out:
# (6531, 9)

# %%
y_train.shape
# Out:
# (6531,)

# %%
X_test.shape
# Out:
# (4355, 9)

# %%
y_test.shape
# Out:
# (4355,)

# %% [markdown]
# ## Task B: Predictive Modeling

# %% [markdown]
# ### Normalize data

# %%
#import module
from sklearn.preprocessing import MinMaxScaler

#fit to training set
scaler = MinMaxScaler().fit(X_train)

# %%
# Transform training X
train_X_scale = scaler.transform(X_train)
train_X_scale = pd.DataFrame(train_X_scale)
train_X_scale.columns = X_train.columns

train_X_scale.describe().transpose()
# Out:
#              count      mean       std  min       25%       50%       75%  max
# hour        6531.0  0.499764  0.301422  0.0  0.217391  0.521739  0.739130  1.0
# season      6531.0  0.502475  0.371898  0.0  0.333333  0.666667  1.000000  1.0
# holiday     6531.0  0.029398  0.168933  0.0  0.000000  0.000000  0.000000  1.0
# workingday  6531.0  0.686112  0.464107  0.0  0.000000  1.000000  1.000000  1.0
# weather     6531.0  0.138008  0.209136  0.0  0.000000  0.000000  0.333333  1.0
# temp        6531.0  0.483818  0.194515  0.0  0.326531  0.489796  0.632653  1.0
# atemp       6531.0  0.512886  0.190157  0.0  0.355856  0.525338  0.677928  1.0
# humidity    6531.0  0.618331  0.191719  0.0  0.470000  0.620000  0.770000  1.0
# windspeed   6531.0  0.224550  0.143902  0.0  0.122840  0.228047  0.298225  1.0

# %%
# Transform test X
test_X_scale = scaler.transform(X_test)
test_X_scale = pd.DataFrame(test_X_scale)
test_X_scale.columns = X_test.columns

test_X_scale.describe().transpose()
# Out:
#              count      mean       std  min       25%       50%       75%  \
# hour        4355.0  0.504877  0.299593  0.0  0.260870  0.521739  0.782609
# season      4355.0  0.501799  0.372340  0.0  0.333333  0.666667  1.000000
# holiday     4355.0  0.027325  0.163047  0.0  0.000000  0.000000  0.000000
# workingday  4355.0  0.673020  0.469164  0.0  0.000000  1.000000  1.000000
# weather     4355.0  0.141676  0.214459  0.0  0.000000  0.000000  0.333333
# temp        4355.0  0.482017  0.193034  0.0  0.326531  0.489796  0.632653
# atemp       4355.0  0.511300  0.188803  0.0  0.355856  0.525338  0.677928
# humidity    4355.0  0.619665  0.193562  0.0  0.470000  0.620000  0.780000
# windspeed   4355.0  0.224583  0.142271  0.0  0.122840  0.228047  0.298225
#
#                  max
# hour        1.000000
# season      1.000000
# holiday     1.000000
# workingday  1.000000
# weather     0.666667
# temp        0.959184
# atemp       0.982996
# humidity    1.000000
# windspeed   1.000000

# %% [markdown]
# ### k-NN Prediction

# %% [markdown]
# First, a prediction with default parameters will set a baseline to compare to the tuned model

# %%
#import regression module
from sklearn.neighbors import KNeighborsClassifier

# KNN: K=5, default distance measurement
knn = KNeighborsClassifier()

#fit data
knn.fit(train_X_scale, y_train)
# Out:
# KNeighborsClassifier()

# %%
#import rmse module
from sklearn.metrics import mean_squared_error

#predict data
pred_knn = knn.predict(test_X_scale)

#compare values
print("Root mean squared error is: " + str(mean_squared_error(y_test, pred_knn, squared=False)))
# Out:
# Root mean squared error is: 143.52854958682707

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# now, the neighbors parameter needs to be tuned, and accuracy statistics need to be printed out to compare for each neighbor

# %%
#import other accuracy modules
from sklearn.metrics import mean_absolute_error, r2_score

#change hyperparameters, show accuracy statistics
for k in range(15):
    k = k + 1
    knn = KNeighborsClassifier(n_neighbors = k, 
                                         weights='uniform', 
                                         algorithm='auto')
    knn.fit(train_X_scale, y_train)
    pred_y = knn.predict(test_X_scale)
    print("the number of neighbors is " + str(k))
    print("Root mean squared error is: " + str(mean_squared_error(y_test, pred_y, squared=False)))
    print("Mean absolute error is: " + str(mean_absolute_error(y_test, pred_y)))
    print("R-squared score is: " + str(r2_score(y_test, pred_y)))
    print("")
# Out:
# the number of neighbors is 1
# Root mean squared error is: 114.89294472927773
# Mean absolute error is: 72.70470723306545
# R-squared score is: 0.5915303133539932
#
# the number of neighbors is 2
# Root mean squared error is: 113.96718261904037
# Mean absolute error is: 70.99586681974742
# R-squared score is: 0.5980863692571262
#
# the number of neighbors is 3
# Root mean squared error is: 126.18865653412547
# Mean absolute error is: 78.40642939150402
# R-squared score is: 0.5072646232743265
#
# the number of neighbors is 4
# Root mean squared error is: 135.51223651646595
# Mean absolute error is: 84.801607347876
# R-squared score is: 0.431762178148158
#
# the number of neighbors is 5
# Root mean squared error is: 143.52854958682707
# Mean absolute error is: 90.67554535017221
# R-squared score is: 0.3625447485710279
#
# the number of neighbors is 6
# Root mean squared error is: 149.01211240730484
# Mean absolute error is: 95.07256027554536
# R-squared score is: 0.31290584571584734
#
# the number of neighbors is 7
# Root mean squared error is: 154.23072015711946
# Mean absolute error is: 98.98553386911595
# R-squared score is: 0.2639371755068427
#
# the number of neighbors is 8
# Root mean squared error is: 158.77154048062306
# Mean absolute error is: 102.43421354764638
# R-squared score is: 0.21995720814615527
#
# the number of neighbors is 9
# Root mean squared error is: 163.13651879878537
# Mean absolute error is: 105.51274397244546
# R-squared score is: 0.1764774568219658
#
# the number of neighbors is 10
# Root mean squared error is: 166.23752389674337
# Mean absolute error is: 107.56601607347876
# R-squared score is: 0.14487178971905124
#
# the number of neighbors is 11
# Root mean squared error is: 168.0221057295059
# Mean absolute error is: 109.14236509758898
# R-squared score is: 0.1264134129678104
#
# the number of neighbors is 12
# Root mean squared error is: 169.0807625012107
# Mean absolute error is: 109.84316877152698
# R-squared score is: 0.11537031974250955
#
# the number of neighbors is 13
# Root mean squared error is: 169.89931306113405
# Mean absolute error is: 110.36670493685419
# R-squared score is: 0.10678428200421408
#
# the number of neighbors is 14
# Root mean squared error is: 171.08421261799188
# Mean absolute error is: 111.1662456946039
# R-squared score is: 0.0942820358633557
#
# the number of neighbors is 15
# Root mean squared error is: 172.6683767002074
# Mean absolute error is: 111.96280137772675
# R-squared score is: 0.07743128524214204
